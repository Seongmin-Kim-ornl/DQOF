# %%
import numpy as np

#print('======================== hyper parameters ==========================')
problem_size = 40
sub_n = 4         # sub-HOBO size
parallel_n = 10  # how many trials at once?
DQAOA_size = problem_size   # how much is distributed?
#print('============================ HOBO file ==============================')

print('Minimum number of cores for iterations:', parallel_n*DQAOA_size +parallel_n +1)
# Out:
# Minimum number of cores for iterations: 411
